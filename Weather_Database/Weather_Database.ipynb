# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from citipy import citipy 
from config import weather_api_key
import time
from datetime import datetime

# %%
# Create a  new set of 2,000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination using citypy module
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

#Perform a API call with the OpenWeathermap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_descript =city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_descript})
                          
                           

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cape town
# Processing Record 2 of Set 1 | katsuura
# Processing Record 3 of Set 1 | mongu
# Processing Record 4 of Set 1 | new norfolk
# Processing Record 5 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | adrar
# Processing Record 8 of Set 1 | luba
# Processing Record 9 of Set 1 | victoria
# Processing Record 10 of Set 1 | villa maria
# Processing Record 11 of Set 1 | garowe
# Processing Record 12 of Set 1 | svetlaya
# Processing Record 13 of Set 1 | kalavai
# Processing Record 14 of Set 1 | qaanaaq
# Processing Record 15 of Set 1 | kodiak
# Processing Record 16 of Set 1 | oranjemund
# Processing Record 17 of Set 1 | korop
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | luanda
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | port hardy
# Processing Record 22 of Set 1 | yoichi
# Processing Record 23 of Set 1 | carnarvon
# Processing Record 24 of Set 1 | hualmay
# Processing Record 25 of Set 1 | sibolga
# Processing Record 26 of Set 1 | puerto leguizamo
# Processing Record 27 of Set 1 | hami
# Processing Record 28 of Set 1 | lavrentiya
# Processing Record 29 of Set 1 | mataura
# Processing Record 30 of Set 1 | barrow
# Processing Record 31 of Set 1 | vaini
# Processing Record 32 of Set 1 | rikitea
# Processing Record 33 of Set 1 | salinopolis
# Processing Record 34 of Set 1 | norman wells
# Processing Record 35 of Set 1 | ancud
# Processing Record 36 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 1 | cherskiy
# Processing Record 38 of Set 1 | vaniyambadi
# Processing Record 39 of Set 1 | merauke
# Processing Record 40 of Set 1 | el sauzal
# Processing Record 41 of Set 1 | jhalida
# Processing Record 42 of Set 1 | bredasdorp
# Processing Record 43 of Set 1 | huangpu
# Processing Record 44 of Set 1 | tasiilaq
# Processing Record 45 of Set 1 | codrington
# Processing Record 46 of Set 1 | chokurdakh
# Processing Record 47 of Set 1 | san cristobal
# Processing Record 48 of Set 1 | nova olimpia
# Processing Record 49 of Set 1 | ribeira grande
# Processing Record 50 of Set 1 | souillac
# Processing Record 1 of Set 2 | atuona
# Processing Record 2 of Set 2 | villa constitucion
# Processing Record 3 of Set 2 | rawson
# Processing Record 4 of Set 2 | el cobre
# Processing Record 5 of Set 2 | chuy
# Processing Record 6 of Set 2 | torbay
# Processing Record 7 of Set 2 | hasaki
# Processing Record 8 of Set 2 | faanui
# Processing Record 9 of Set 2 | hithadhoo
# Processing Record 10 of Set 2 | shirokiy
# Processing Record 11 of Set 2 | saint stephen
# Processing Record 12 of Set 2 | gravdal
# Processing Record 13 of Set 2 | tiksi
# Processing Record 14 of Set 2 | tuatapere
# Processing Record 15 of Set 2 | letlhakane
# Processing Record 16 of Set 2 | kibungo
# Processing Record 17 of Set 2 | khatanga
# Processing Record 18 of Set 2 | mar del plata
# Processing Record 19 of Set 2 | sao filipe
# Processing Record 20 of Set 2 | saint anthony
# Processing Record 21 of Set 2 | poum
# Processing Record 22 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 2 | panalingaan
# Processing Record 24 of Set 2 | vila franca do campo
# Processing Record 25 of Set 2 | alofi
# Processing Record 26 of Set 2 | muswellbrook
# Processing Record 27 of Set 2 | veraval
# Processing Record 28 of Set 2 | hilo
# Processing Record 29 of Set 2 | sadiqabad
# Processing Record 30 of Set 2 | saldanha
# Processing Record 31 of Set 2 | nikolskoye
# Processing Record 32 of Set 2 | chesma
# Processing Record 33 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 34 of Set 2 | hermanus
# Processing Record 35 of Set 2 | berlevag
# Processing Record 36 of Set 2 | shingu
# Processing Record 37 of Set 2 | luderitz
# Processing Record 38 of Set 2 | avera
# Processing Record 39 of Set 2 | chahal
# Processing Record 40 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 2 | salekhard
# Processing Record 43 of Set 2 | aitape
# Processing Record 44 of Set 2 | esperance
# Processing Record 45 of Set 2 | rogozno
# Processing Record 46 of Set 2 | coquimbo
# Processing Record 47 of Set 2 | puerto ayora
# Processing Record 48 of Set 2 | gizo
# Processing Record 49 of Set 2 | la ronge
# Processing Record 50 of Set 2 | neiafu
# Processing Record 1 of Set 3 | caravelas
# Processing Record 2 of Set 3 | vilhena
# Processing Record 3 of Set 3 | lebu
# Processing Record 4 of Set 3 | snezhnogorsk
# Processing Record 5 of Set 3 | saint george
# Processing Record 6 of Set 3 | hobart
# Processing Record 7 of Set 3 | pangai
# Processing Record 8 of Set 3 | castro
# Processing Record 9 of Set 3 | port alfred
# Processing Record 10 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 11 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 12 of Set 3 | bondo
# Processing Record 13 of Set 3 | saint-joseph
# Processing Record 14 of Set 3 | dzhusaly
# City not found. Skipping...
# Processing Record 15 of Set 3 | sao jose da coroa grande
# Processing Record 16 of Set 3 | talnakh
# Processing Record 17 of Set 3 | lorengau
# Processing Record 18 of Set 3 | saint-philippe
# Processing Record 19 of Set 3 | bluff
# Processing Record 20 of Set 3 | esna
# Processing Record 21 of Set 3 | portree
# Processing Record 22 of Set 3 | ferme-neuve
# Processing Record 23 of Set 3 | yinchuan
# Processing Record 24 of Set 3 | marawi
# Processing Record 25 of Set 3 | ponta do sol
# Processing Record 26 of Set 3 | abramovka
# Processing Record 27 of Set 3 | waingapu
# Processing Record 28 of Set 3 | jamestown
# Processing Record 29 of Set 3 | necochea
# Processing Record 30 of Set 3 | havelock
# Processing Record 31 of Set 3 | madras
# Processing Record 32 of Set 3 | novyy urengoy
# Processing Record 33 of Set 3 | prachuap khiri khan
# Processing Record 34 of Set 3 | the valley
# Processing Record 35 of Set 3 | butaritari
# Processing Record 36 of Set 3 | tessalit
# Processing Record 37 of Set 3 | tecoanapa
# Processing Record 38 of Set 3 | kapaa
# Processing Record 39 of Set 3 | constitucion
# Processing Record 40 of Set 3 | kedougou
# Processing Record 41 of Set 3 | mahebourg
# Processing Record 42 of Set 3 | zhezkazgan
# Processing Record 43 of Set 3 | college
# Processing Record 44 of Set 3 | salalah
# Processing Record 45 of Set 3 | bethel
# Processing Record 46 of Set 3 | pisco
# Processing Record 47 of Set 3 | busselton
# Processing Record 48 of Set 3 | guerrero negro
# Processing Record 49 of Set 3 | sitka
# Processing Record 50 of Set 3 | sao felix do xingu
# Processing Record 1 of Set 4 | san quintin
# Processing Record 2 of Set 4 | bengkulu
# Processing Record 3 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 4 | padang
# Processing Record 5 of Set 4 | faya
# Processing Record 6 of Set 4 | pombas
# Processing Record 7 of Set 4 | vanimo
# Processing Record 8 of Set 4 | zheleznodorozhnyy
# Processing Record 9 of Set 4 | anadyr
# Processing Record 10 of Set 4 | kekri
# Processing Record 11 of Set 4 | namibe
# Processing Record 12 of Set 4 | kavieng
# Processing Record 13 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 4 | fare
# Processing Record 15 of Set 4 | tuggurt
# City not found. Skipping...
# Processing Record 16 of Set 4 | grindavik
# Processing Record 17 of Set 4 | zhigalovo
# Processing Record 18 of Set 4 | pisz
# Processing Record 19 of Set 4 | cam ranh
# Processing Record 20 of Set 4 | narsaq
# Processing Record 21 of Set 4 | ca mau
# Processing Record 22 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 23 of Set 4 | moose factory
# Processing Record 24 of Set 4 | kahului
# Processing Record 25 of Set 4 | linkoping
# Processing Record 26 of Set 4 | arraial do cabo
# Processing Record 27 of Set 4 | tilichiki
# Processing Record 28 of Set 4 | saskylakh
# Processing Record 29 of Set 4 | blacksburg
# Processing Record 30 of Set 4 | nizhnyaya tavda
# Processing Record 31 of Set 4 | north tonawanda
# Processing Record 32 of Set 4 | cidreira
# Processing Record 33 of Set 4 | tuktoyaktuk
# Processing Record 34 of Set 4 | hamilton
# Processing Record 35 of Set 4 | sola
# Processing Record 36 of Set 4 | tekirdag
# Processing Record 37 of Set 4 | soledade
# Processing Record 38 of Set 4 | azimur
# City not found. Skipping...
# Processing Record 39 of Set 4 | sorland
# Processing Record 40 of Set 4 | kovur
# Processing Record 41 of Set 4 | provideniya
# Processing Record 42 of Set 4 | fairbanks
# Processing Record 43 of Set 4 | haines junction
# Processing Record 44 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 45 of Set 4 | karratha
# Processing Record 46 of Set 4 | hobyo
# Processing Record 47 of Set 4 | mayo
# Processing Record 48 of Set 4 | salta
# Processing Record 49 of Set 4 | broome
# Processing Record 50 of Set 4 | kaitangata
# Processing Record 1 of Set 5 | ugoofaaru
# Processing Record 2 of Set 5 | oktyabrskiy
# Processing Record 3 of Set 5 | theologos
# City not found. Skipping...
# Processing Record 4 of Set 5 | great falls
# Processing Record 5 of Set 5 | dargaville
# Processing Record 6 of Set 5 | uwayl
# City not found. Skipping...
# Processing Record 7 of Set 5 | kiruna
# Processing Record 8 of Set 5 | yellowknife
# Processing Record 9 of Set 5 | thompson
# Processing Record 10 of Set 5 | minot
# Processing Record 11 of Set 5 | roma
# Processing Record 12 of Set 5 | chernyshevsk
# Processing Record 13 of Set 5 | dingle
# Processing Record 14 of Set 5 | ulaangom
# Processing Record 15 of Set 5 | majene
# Processing Record 16 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 5 | mehamn
# Processing Record 18 of Set 5 | eureka
# Processing Record 19 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 5 | marystown
# Processing Record 21 of Set 5 | iwanai
# Processing Record 22 of Set 5 | talcahuano
# Processing Record 23 of Set 5 | lasa
# Processing Record 24 of Set 5 | tabou
# Processing Record 25 of Set 5 | concordia
# Processing Record 26 of Set 5 | ilulissat
# Processing Record 27 of Set 5 | coffs harbour
# Processing Record 28 of Set 5 | baracoa
# Processing Record 29 of Set 5 | potam
# Processing Record 30 of Set 5 | naze
# Processing Record 31 of Set 5 | bratsk
# Processing Record 32 of Set 5 | hervey bay
# Processing Record 33 of Set 5 | ostrovnoy
# Processing Record 34 of Set 5 | lodja
# Processing Record 35 of Set 5 | loubomo
# Processing Record 36 of Set 5 | ksenyevka
# City not found. Skipping...
# Processing Record 37 of Set 5 | athabasca
# Processing Record 38 of Set 5 | kysyl-syr
# Processing Record 39 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 5 | rio branco do sul
# Processing Record 41 of Set 5 | bajo baudo
# City not found. Skipping...
# Processing Record 42 of Set 5 | itaituba
# Processing Record 43 of Set 5 | georgetown
# Processing Record 44 of Set 5 | jabiru
# City not found. Skipping...
# Processing Record 45 of Set 5 | ayorou
# Processing Record 46 of Set 5 | porto novo
# Processing Record 47 of Set 5 | seoul
# Processing Record 48 of Set 5 | upernavik
# Processing Record 49 of Set 5 | mozelos
# Processing Record 50 of Set 5 | pyay
# Processing Record 1 of Set 6 | tucupita
# Processing Record 2 of Set 6 | kamina
# Processing Record 3 of Set 6 | pevek
# Processing Record 4 of Set 6 | ust-nera
# Processing Record 5 of Set 6 | alice springs
# Processing Record 6 of Set 6 | chumikan
# Processing Record 7 of Set 6 | longyearbyen
# Processing Record 8 of Set 6 | biak
# Processing Record 9 of Set 6 | bathsheba
# Processing Record 10 of Set 6 | yeniseysk
# Processing Record 11 of Set 6 | sulangan
# Processing Record 12 of Set 6 | kommunisticheskiy
# Processing Record 13 of Set 6 | gat
# Processing Record 14 of Set 6 | antalaha
# Processing Record 15 of Set 6 | bambous virieux
# Processing Record 16 of Set 6 | carmen
# Processing Record 17 of Set 6 | byron bay
# Processing Record 18 of Set 6 | olinda
# Processing Record 19 of Set 6 | coahuayana
# Processing Record 20 of Set 6 | svelgen
# Processing Record 21 of Set 6 | cap-aux-meules
# Processing Record 22 of Set 6 | manokwari
# Processing Record 23 of Set 6 | beckley
# Processing Record 24 of Set 6 | rodeo
# Processing Record 25 of Set 6 | aklavik
# Processing Record 26 of Set 6 | carutapera
# Processing Record 27 of Set 6 | clyde river
# Processing Record 28 of Set 6 | erenhot
# Processing Record 29 of Set 6 | severo-kurilsk
# Processing Record 30 of Set 6 | mildura
# Processing Record 31 of Set 6 | krasnovishersk
# Processing Record 32 of Set 6 | hofn
# Processing Record 33 of Set 6 | diamantino
# Processing Record 34 of Set 6 | oxford
# Processing Record 35 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 6 | otane
# Processing Record 37 of Set 6 | ruteng
# Processing Record 38 of Set 6 | tambo
# Processing Record 39 of Set 6 | avarua
# Processing Record 40 of Set 6 | cabo san lucas
# Processing Record 41 of Set 6 | fano
# Processing Record 42 of Set 6 | muros
# Processing Record 43 of Set 6 | sedelnikovo
# City not found. Skipping...
# Processing Record 44 of Set 6 | sao joao da barra
# Processing Record 45 of Set 6 | bayir
# Processing Record 46 of Set 6 | baruun-urt
# Processing Record 47 of Set 6 | wabrzezno
# Processing Record 48 of Set 6 | nongan
# Processing Record 49 of Set 6 | pacifica
# Processing Record 50 of Set 6 | chaupal
# Processing Record 1 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 7 | cockburn harbour
# City not found. Skipping...
# Processing Record 3 of Set 7 | lompoc
# Processing Record 4 of Set 7 | broken hill
# Processing Record 5 of Set 7 | tigil
# Processing Record 6 of Set 7 | alindao
# Processing Record 7 of Set 7 | sinnamary
# Processing Record 8 of Set 7 | achit
# Processing Record 9 of Set 7 | opaka
# Processing Record 10 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 7 | pemangkat
# Processing Record 12 of Set 7 | road town
# Processing Record 13 of Set 7 | saint-georges
# Processing Record 14 of Set 7 | cukai
# Processing Record 15 of Set 7 | dikson
# Processing Record 16 of Set 7 | turtas
# Processing Record 17 of Set 7 | dinghai
# Processing Record 18 of Set 7 | tahe
# Processing Record 19 of Set 7 | jiancheng
# Processing Record 20 of Set 7 | belaya gora
# Processing Record 21 of Set 7 | balabac
# Processing Record 22 of Set 7 | ambilobe
# Processing Record 23 of Set 7 | hohhot
# Processing Record 24 of Set 7 | vidim
# Processing Record 25 of Set 7 | harper
# Processing Record 26 of Set 7 | magadan
# Processing Record 27 of Set 7 | crotone
# Processing Record 28 of Set 7 | guider
# Processing Record 29 of Set 7 | arlit
# Processing Record 30 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 31 of Set 7 | fort nelson
# Processing Record 32 of Set 7 | kruisfontein
# Processing Record 33 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 34 of Set 7 | ouesso
# Processing Record 35 of Set 7 | prince rupert
# Processing Record 36 of Set 7 | tautira
# Processing Record 37 of Set 7 | quang ngai
# Processing Record 38 of Set 7 | tiznit
# Processing Record 39 of Set 7 | dwarka
# Processing Record 40 of Set 7 | biltine
# Processing Record 41 of Set 7 | iqaluit
# Processing Record 42 of Set 7 | ngunguru
# Processing Record 43 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 44 of Set 7 | anchorage
# Processing Record 45 of Set 7 | bud
# Processing Record 46 of Set 7 | monrovia
# Processing Record 47 of Set 7 | voh
# Processing Record 48 of Set 7 | nanortalik
# Processing Record 49 of Set 7 | mantua
# Processing Record 50 of Set 7 | japura
# Processing Record 1 of Set 8 | mujiayingzi
# Processing Record 2 of Set 8 | deniliquin
# Processing Record 3 of Set 8 | gorontalo
# Processing Record 4 of Set 8 | griffith
# Processing Record 5 of Set 8 | santa rosa
# Processing Record 6 of Set 8 | usila
# City not found. Skipping...
# Processing Record 7 of Set 8 | bubaque
# Processing Record 8 of Set 8 | opobo
# City not found. Skipping...
# Processing Record 9 of Set 8 | dapaong
# Processing Record 10 of Set 8 | galeana
# Processing Record 11 of Set 8 | port hedland
# Processing Record 12 of Set 8 | hernani
# Processing Record 13 of Set 8 | srednekolymsk
# Processing Record 14 of Set 8 | bida
# Processing Record 15 of Set 8 | isangel
# Processing Record 16 of Set 8 | saint-pierre
# Processing Record 17 of Set 8 | svetlogorsk
# Processing Record 18 of Set 8 | howard springs
# Processing Record 19 of Set 8 | teguldet
# Processing Record 20 of Set 8 | paita
# Processing Record 21 of Set 8 | sobolevo
# Processing Record 22 of Set 8 | east london
# Processing Record 23 of Set 8 | amroli
# Processing Record 24 of Set 8 | west bay
# Processing Record 25 of Set 8 | juneau
# Processing Record 26 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 8 | praia
# Processing Record 28 of Set 8 | nyurba
# Processing Record 29 of Set 8 | lucea
# Processing Record 30 of Set 8 | chernyshevskiy
# Processing Record 31 of Set 8 | rundu
# Processing Record 32 of Set 8 | baghdad
# Processing Record 33 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 8 | tomatlan
# Processing Record 35 of Set 8 | takob
# City not found. Skipping...
# Processing Record 36 of Set 8 | zhuji
# Processing Record 37 of Set 8 | takanabe
# Processing Record 38 of Set 8 | ruidoso
# Processing Record 39 of Set 8 | vikhorevka
# Processing Record 40 of Set 8 | englehart
# Processing Record 41 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 8 | sabang
# Processing Record 43 of Set 8 | kirakira
# Processing Record 44 of Set 8 | imeni poliny osipenko
# Processing Record 45 of Set 8 | siemiatycze
# Processing Record 46 of Set 8 | suifenhe
# Processing Record 47 of Set 8 | lipari
# Processing Record 48 of Set 8 | diego de almagro
# Processing Record 49 of Set 8 | cockburn town
# Processing Record 50 of Set 8 | vostok
# Processing Record 1 of Set 9 | kaeng khlo
# City not found. Skipping...
# Processing Record 2 of Set 9 | yayva
# Processing Record 3 of Set 9 | oranjestad
# Processing Record 4 of Set 9 | port elizabeth
# Processing Record 5 of Set 9 | leningradskiy
# Processing Record 6 of Set 9 | guiberoua
# Processing Record 7 of Set 9 | soloneshnoye
# Processing Record 8 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 9 | whitehorse
# Processing Record 10 of Set 9 | isoka
# Processing Record 11 of Set 9 | santa cruz cabralia
# Processing Record 12 of Set 9 | geraldton
# Processing Record 13 of Set 9 | paris
# Processing Record 14 of Set 9 | skibbereen
# Processing Record 15 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 16 of Set 9 | deputatskiy
# Processing Record 17 of Set 9 | ferrol
# Processing Record 18 of Set 9 | tartagal
# Processing Record 19 of Set 9 | guanica
# Processing Record 20 of Set 9 | lac-megantic
# Processing Record 21 of Set 9 | payo
# Processing Record 22 of Set 9 | slave lake
# Processing Record 23 of Set 9 | aykhal
# Processing Record 24 of Set 9 | asau
# Processing Record 25 of Set 9 | bainbridge
# Processing Record 26 of Set 9 | hazaribag
# Processing Record 27 of Set 9 | quatre cocos
# Processing Record 28 of Set 9 | okha
# Processing Record 29 of Set 9 | kalyazin
# Processing Record 30 of Set 9 | havoysund
# Processing Record 31 of Set 9 | yershov
# Processing Record 32 of Set 9 | rock sound
# Processing Record 33 of Set 9 | amapa
# Processing Record 34 of Set 9 | bamberg
# Processing Record 35 of Set 9 | cayenne
# Processing Record 36 of Set 9 | micheweni
# Processing Record 37 of Set 9 | cruzeiro do sul
# Processing Record 38 of Set 9 | lagos
# Processing Record 39 of Set 9 | talca
# Processing Record 40 of Set 9 | nome
# Processing Record 41 of Set 9 | lesogorsk
# Processing Record 42 of Set 9 | san patricio
# Processing Record 43 of Set 9 | colares
# Processing Record 44 of Set 9 | pokhara
# Processing Record 45 of Set 9 | sindand
# City not found. Skipping...
# Processing Record 46 of Set 9 | belmonte
# Processing Record 47 of Set 9 | yatou
# Processing Record 48 of Set 9 | klaksvik
# Processing Record 49 of Set 9 | milkovo
# Processing Record 50 of Set 9 | colac
# Processing Record 1 of Set 10 | buritis
# Processing Record 2 of Set 10 | kalmar
# Processing Record 3 of Set 10 | karema
# Processing Record 4 of Set 10 | lukiv
# Processing Record 5 of Set 10 | tazovskiy
# Processing Record 6 of Set 10 | kudahuvadhoo
# Processing Record 7 of Set 10 | mount vernon
# Processing Record 8 of Set 10 | camacari
# Processing Record 9 of Set 10 | henties bay
# Processing Record 10 of Set 10 | san policarpo
# Processing Record 11 of Set 10 | tubuala
# Processing Record 12 of Set 10 | arman
# Processing Record 13 of Set 10 | kimberley
# Processing Record 14 of Set 10 | nador
# Processing Record 15 of Set 10 | nemuro
# Processing Record 16 of Set 10 | westport
# Processing Record 17 of Set 10 | keti bandar
# Processing Record 18 of Set 10 | hambantota
# Processing Record 19 of Set 10 | pangnirtung
# Processing Record 20 of Set 10 | moron
# Processing Record 21 of Set 10 | labuhan
# Processing Record 22 of Set 10 | ancona
# Processing Record 23 of Set 10 | canico
# Processing Record 24 of Set 10 | keetmanshoop
# Processing Record 25 of Set 10 | kaoma
# Processing Record 26 of Set 10 | trinidad
# Processing Record 27 of Set 10 | mandalgovi
# Processing Record 28 of Set 10 | burgeo
# Processing Record 29 of Set 10 | mbuji-mayi
# Processing Record 30 of Set 10 | airai
# Processing Record 31 of Set 10 | ishigaki
# Processing Record 32 of Set 10 | puri
# Processing Record 33 of Set 10 | tuskegee
# Processing Record 34 of Set 10 | bassano
# Processing Record 35 of Set 10 | kilindoni
# Processing Record 36 of Set 10 | evensk
# Processing Record 37 of Set 10 | ixtapa
# Processing Record 38 of Set 10 | port lincoln
# Processing Record 39 of Set 10 | gazojak
# Processing Record 40 of Set 10 | panchagarh
# Processing Record 41 of Set 10 | acari
# Processing Record 42 of Set 10 | fortuna
# Processing Record 43 of Set 10 | aksu
# Processing Record 44 of Set 10 | fort-shevchenko
# Processing Record 45 of Set 10 | morag
# Processing Record 46 of Set 10 | kholmogory
# Processing Record 47 of Set 10 | komsomolskiy
# Processing Record 48 of Set 10 | shieli
# Processing Record 49 of Set 10 | mountain home
# Processing Record 50 of Set 10 | touros
# Processing Record 1 of Set 11 | maracas
# Processing Record 2 of Set 11 | mocambique
# City not found. Skipping...
# Processing Record 3 of Set 11 | rolla
# Processing Record 4 of Set 11 | huarmey
# Processing Record 5 of Set 11 | claremore
# Processing Record 6 of Set 11 | moranbah
# Processing Record 7 of Set 11 | nakamura
# Processing Record 8 of Set 11 | phrai bung
# City not found. Skipping...
# Processing Record 9 of Set 11 | urengoy
# Processing Record 10 of Set 11 | buraydah
# Processing Record 11 of Set 11 | bilibino
# Processing Record 12 of Set 11 | manicore
# Processing Record 13 of Set 11 | jackson
# Processing Record 14 of Set 11 | kirando
# Processing Record 15 of Set 11 | pantai remis
# Processing Record 16 of Set 11 | matara
# Processing Record 17 of Set 11 | rio grande
# Processing Record 18 of Set 11 | korla
# Processing Record 19 of Set 11 | muisne
# Processing Record 20 of Set 11 | bairiki
# Processing Record 21 of Set 11 | baykit
# Processing Record 22 of Set 11 | iskilip
# Processing Record 23 of Set 11 | cascais
# Processing Record 24 of Set 11 | tandil
# Processing Record 25 of Set 11 | fuyu
# Processing Record 26 of Set 11 | yarovoye
# Processing Record 27 of Set 11 | kralendijk
# Processing Record 28 of Set 11 | vardo
# Processing Record 29 of Set 11 | prado
# Processing Record 30 of Set 11 | huilong
# Processing Record 31 of Set 11 | san rafael del sur
# Processing Record 32 of Set 11 | de aar
# Processing Record 33 of Set 11 | los llanos de aridane
# Processing Record 34 of Set 11 | florianopolis
# Processing Record 35 of Set 11 | singleton
# Processing Record 36 of Set 11 | balkanabat
# Processing Record 37 of Set 11 | chicama
# Processing Record 38 of Set 11 | donghai
# Processing Record 39 of Set 11 | carlsbad
# Processing Record 40 of Set 11 | lavumisa
# Processing Record 41 of Set 11 | ornskoldsvik
# Processing Record 42 of Set 11 | saint-augustin
# Processing Record 43 of Set 11 | umm lajj
# Processing Record 44 of Set 11 | turukhansk
# Processing Record 45 of Set 11 | mount gambier
# Processing Record 46 of Set 11 | taltal
# Processing Record 47 of Set 11 | homer
# Processing Record 48 of Set 11 | nahrin
# Processing Record 49 of Set 11 | ahmadnagar
# Processing Record 50 of Set 11 | kajiado
# Processing Record 1 of Set 12 | sabzevar
# Processing Record 2 of Set 12 | northam
# Processing Record 3 of Set 12 | wanaka
# Processing Record 4 of Set 12 | huaicheng
# Processing Record 5 of Set 12 | beyneu
# Processing Record 6 of Set 12 | potiskum
# Processing Record 7 of Set 12 | armacao dos buzios
# City not found. Skipping...
# Processing Record 8 of Set 12 | bereda
# Processing Record 9 of Set 12 | melilla
# Processing Record 10 of Set 12 | imbituba
# Processing Record 11 of Set 12 | qaqortoq
# Processing Record 12 of Set 12 | san juan bautista
# Processing Record 13 of Set 12 | morondava
# Processing Record 14 of Set 12 | bodden town
# Processing Record 15 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 16 of Set 12 | luganville
# Processing Record 17 of Set 12 | moundou
# Processing Record 18 of Set 12 | bonthe
# Processing Record 19 of Set 12 | semnan
# Processing Record 20 of Set 12 | viedma
# Processing Record 21 of Set 12 | mbandaka
# Processing Record 22 of Set 12 | kutum
# Processing Record 23 of Set 12 | talas
# Processing Record 24 of Set 12 | brownsville
# Processing Record 25 of Set 12 | marsh harbour
# Processing Record 26 of Set 12 | richards bay
# Processing Record 27 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 28 of Set 12 | ijaki
# City not found. Skipping...
# Processing Record 29 of Set 12 | lac du bonnet
# Processing Record 30 of Set 12 | kavaratti
# Processing Record 31 of Set 12 | tigzirt
# Processing Record 32 of Set 12 | husavik
# Processing Record 33 of Set 12 | manado
# Processing Record 34 of Set 12 | buala
# Processing Record 35 of Set 12 | bayanday
# Processing Record 36 of Set 12 | quesnel
# Processing Record 37 of Set 12 | yemtsa
# Processing Record 38 of Set 12 | kamaishi
# Processing Record 39 of Set 12 | vao
# Processing Record 40 of Set 12 | podor
# Processing Record 41 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 42 of Set 12 | sudak
# Processing Record 43 of Set 12 | havre-saint-pierre
# Processing Record 44 of Set 12 | lincoln
# Processing Record 45 of Set 12 | araouane
# Processing Record 46 of Set 12 | chongqing
# Processing Record 47 of Set 12 | igrim
# Processing Record 48 of Set 12 | novikovo
# Processing Record 49 of Set 12 | vestmanna
# Processing Record 50 of Set 12 | artemisa
# Processing Record 1 of Set 13 | maicao
# Processing Record 2 of Set 13 | xai-xai
# Processing Record 3 of Set 13 | laguna
# Processing Record 4 of Set 13 | nakhon si thammarat
# Processing Record 5 of Set 13 | cuajinicuilapa
# Processing Record 6 of Set 13 | esso
# Processing Record 7 of Set 13 | elliot lake
# Processing Record 8 of Set 13 | dolores
# Processing Record 9 of Set 13 | mudgee
# Processing Record 10 of Set 13 | magadi
# Processing Record 11 of Set 13 | katangli
# Processing Record 12 of Set 13 | bowen
# Processing Record 13 of Set 13 | macia
# Processing Record 14 of Set 13 | san juan
# Processing Record 15 of Set 13 | zhigansk
# Processing Record 16 of Set 13 | puerto ayacucho
# Processing Record 17 of Set 13 | egvekinot
# Processing Record 18 of Set 13 | port said
# Processing Record 19 of Set 13 | rio gallegos
# Processing Record 20 of Set 13 | ketchikan
# Processing Record 21 of Set 13 | bengkalis
# City not found. Skipping...
# Processing Record 22 of Set 13 | piriyapatna
# Processing Record 23 of Set 13 | monatele
# City not found. Skipping...
# Processing Record 24 of Set 13 | ramasukha
# City not found. Skipping...
# Processing Record 25 of Set 13 | ahipara
# Processing Record 26 of Set 13 | hailar
# Processing Record 27 of Set 13 | inhambane
# Processing Record 28 of Set 13 | belyy yar
# Processing Record 29 of Set 13 | kidal
# Processing Record 30 of Set 13 | goulburn
# Processing Record 31 of Set 13 | naliya
# Processing Record 32 of Set 13 | corinto
# Processing Record 33 of Set 13 | ulaanbaatar
# Processing Record 34 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 13 | escondido
# Processing Record 36 of Set 13 | alyangula
# Processing Record 37 of Set 13 | umm kaddadah
# Processing Record 38 of Set 13 | worthing
# Processing Record 39 of Set 13 | tamworth
# Processing Record 40 of Set 13 | mangan
# Processing Record 41 of Set 13 | tabukiniberu
# City not found. Skipping...
# Processing Record 42 of Set 13 | prince george
# Processing Record 43 of Set 13 | khorixas
# Processing Record 44 of Set 13 | ubatuba
# Processing Record 45 of Set 13 | lima
# Processing Record 46 of Set 13 | ust-barguzin
# Processing Record 47 of Set 13 | kununurra
# Processing Record 48 of Set 13 | knysna
# Processing Record 49 of Set 13 | acucena
# Processing Record 50 of Set 13 | xinmin
# Processing Record 1 of Set 14 | comodoro rivadavia
# Processing Record 2 of Set 14 | almeirim
# Processing Record 3 of Set 14 | kota belud
# Processing Record 4 of Set 14 | viransehir
# Processing Record 5 of Set 14 | yar-sale
# Processing Record 6 of Set 14 | buin
# Processing Record 7 of Set 14 | abu dhabi
# Processing Record 8 of Set 14 | madera
# Processing Record 9 of Set 14 | goroka
# Processing Record 10 of Set 14 | celestun
# Processing Record 11 of Set 14 | maryville
# Processing Record 12 of Set 14 | atasu
# Processing Record 13 of Set 14 | pitimbu
# Processing Record 14 of Set 14 | noumea
# Processing Record 15 of Set 14 | dormidontovka
# Processing Record 16 of Set 14 | acapulco
# Processing Record 17 of Set 14 | dona ines
# Processing Record 18 of Set 14 | pacific grove
# Processing Record 19 of Set 14 | botelhos
# Processing Record 20 of Set 14 | olafsvik
# Processing Record 21 of Set 14 | prestea
# Processing Record 22 of Set 14 | zorritos
# Processing Record 23 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 24 of Set 14 | vung tau
# Processing Record 25 of Set 14 | puro
# Processing Record 26 of Set 14 | mwinilunga
# Processing Record 27 of Set 14 | tsaratanana
# Processing Record 28 of Set 14 | palaikastron
# Processing Record 29 of Set 14 | meulaboh
# Processing Record 30 of Set 14 | lubao
# Processing Record 31 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 32 of Set 14 | varhaug
# Processing Record 33 of Set 14 | nieuw amsterdam
# Processing Record 34 of Set 14 | tucurui
# Processing Record 35 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 36 of Set 14 | kyra
# Processing Record 37 of Set 14 | buluang
# Processing Record 38 of Set 14 | portland
# Processing Record 39 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 40 of Set 14 | nzerekore
# Processing Record 41 of Set 14 | zhangye
# Processing Record 42 of Set 14 | kraslava
# Processing Record 43 of Set 14 | sao domingos
# Processing Record 44 of Set 14 | shimanovsk
# Processing Record 45 of Set 14 | mackay
# Processing Record 46 of Set 14 | george town
# Processing Record 47 of Set 14 | jiexiu
# Processing Record 48 of Set 14 | abancay
# Processing Record 49 of Set 14 | djibo
# Processing Record 50 of Set 14 | karpathos
# Processing Record 1 of Set 15 | andevoranto
# City not found. Skipping...
# Processing Record 2 of Set 15 | moyale
# Processing Record 3 of Set 15 | ravar
# Processing Record 4 of Set 15 | lufilufi
# Processing Record 5 of Set 15 | lakes entrance
# Processing Record 6 of Set 15 | lille
# Processing Record 7 of Set 15 | dorokhovo
# Processing Record 8 of Set 15 | marv dasht
# City not found. Skipping...
# Processing Record 9 of Set 15 | exeter
# Processing Record 10 of Set 15 | nurota
# Processing Record 11 of Set 15 | cervo
# Processing Record 12 of Set 15 | killybegs
# Processing Record 13 of Set 15 | jimo
# Processing Record 14 of Set 15 | swift current
# Processing Record 15 of Set 15 | udachnyy
# Processing Record 16 of Set 15 | rocha
# Processing Record 17 of Set 15 | ubinskoye
# Processing Record 18 of Set 15 | singaparna
# Processing Record 19 of Set 15 | sisimiut
# Processing Record 20 of Set 15 | mindif
# Processing Record 21 of Set 15 | kontagora
# Processing Record 22 of Set 15 | zabol
# Processing Record 23 of Set 15 | aanekoski
# Processing Record 24 of Set 15 | greece
# Processing Record 25 of Set 15 | port blair
# Processing Record 26 of Set 15 | caibarien
# Processing Record 27 of Set 15 | marsa matruh
# Processing Record 28 of Set 15 | cesvaine
# Processing Record 29 of Set 15 | kytlym
# City not found. Skipping...
# Processing Record 30 of Set 15 | ballina
# Processing Record 31 of Set 15 | iquique
# Processing Record 32 of Set 15 | shache
# Processing Record 33 of Set 15 | iralaya
# Processing Record 34 of Set 15 | sumbe
# Processing Record 35 of Set 15 | durant
# Processing Record 36 of Set 15 | xuddur
# Processing Record 37 of Set 15 | gazanjyk
# Processing Record 38 of Set 15 | berbera
# Processing Record 39 of Set 15 | santa cruz
# Processing Record 40 of Set 15 | candawaga
# City not found. Skipping...
# Processing Record 41 of Set 15 | krasnoselkup
# Processing Record 42 of Set 15 | le mont-sur-lausanne
# Processing Record 43 of Set 15 | mweka
# Processing Record 44 of Set 15 | la seyne-sur-mer
# Processing Record 45 of Set 15 | camacupa
# Processing Record 46 of Set 15 | nanao
# Processing Record 47 of Set 15 | saint-fabien
# City not found. Skipping...
# Processing Record 48 of Set 15 | ramgarh
# Processing Record 49 of Set 15 | inta
# Processing Record 50 of Set 15 | buon me thuot
# City not found. Skipping...
# Processing Record 1 of Set 16 | belle fourche
# Processing Record 2 of Set 16 | ceyhan
# Processing Record 3 of Set 16 | le pradet
# Processing Record 4 of Set 16 | coihaique
# Processing Record 5 of Set 16 | beloha
# Processing Record 6 of Set 16 | cermik
# Processing Record 7 of Set 16 | tinglev
# Processing Record 8 of Set 16 | mahibadhoo
# Processing Record 9 of Set 16 | najran
# Processing Record 10 of Set 16 | mizdah
# Processing Record 11 of Set 16 | sabanagrande
# Processing Record 12 of Set 16 | barranco
# Processing Record 13 of Set 16 | perelyub
# Processing Record 14 of Set 16 | mocuba
# Processing Record 15 of Set 16 | akhmim
# Processing Record 16 of Set 16 | genk
# Processing Record 17 of Set 16 | red bluff
# Processing Record 18 of Set 16 | kosya
# City not found. Skipping...
# Processing Record 19 of Set 16 | eldikan
# City not found. Skipping...
# Processing Record 20 of Set 16 | tunduru
# City not found. Skipping...
# Processing Record 21 of Set 16 | bonoua
# Processing Record 22 of Set 16 | nguiu
# City not found. Skipping...
# Processing Record 23 of Set 16 | lingao
# Processing Record 24 of Set 16 | gazli
# Processing Record 25 of Set 16 | tangzhai
# Processing Record 26 of Set 16 | general roca
# Processing Record 27 of Set 16 | tura
# Processing Record 28 of Set 16 | shimoda
# Processing Record 29 of Set 16 | noshiro
# Processing Record 30 of Set 16 | priiskovyy
# Processing Record 31 of Set 16 | sangar
# Processing Record 32 of Set 16 | anderson
# Processing Record 33 of Set 16 | springbok
# Processing Record 34 of Set 16 | taoudenni
# Processing Record 35 of Set 16 | aksarka
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Verify number of cities
len(city_data)
# Out:
# 719

# %%
# Convert the array of dictionaries to a Pandas DataFrame. Round Decimals
city_data_df = pd.DataFrame(city_data)
city_data_df = pd.DataFrame(city_data)
city_data_df['Lat'] =city_data_df['Lat'].round(decimals = 2)
city_data_df['Lng'] =city_data_df['Lng'].round(decimals = 2)
city_data_df.head(10)
# Out:
#           City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0    Cape Town      ZA -33.93   18.42     71.10        40           0
# 1     Katsuura      JP  35.13  140.30     69.04        70         100
# 2        Mongu      ZM -15.25   23.13     81.57        19           3
# 3  New Norfolk      AU -42.78  147.06     55.71        72          87
# 4       Albany      US  42.60  -73.97     72.64        69           3
# 5        Adrar      MR  20.50  -10.07    100.11        24          20
# 6         Luba      GQ   3.46    8.55     84.09        85          54
# 7     Victoria      HK  22.29  114.16     84.33        72          94
# 8  Villa Maria      AR -32.41  -63.24     53.33        57          95
# 9       Garowe      SO   8.41   48.48     85.28        49          88
#
#    Wind Speed Current Description
# 0       13.80           clear sky
# 1       21.30     overcast clouds
# 2        7.27           clear sky
# 3        1.01     overcast clouds
# 4        1.01           clear sky
# 5       18.19          few clouds
# 6        7.23       broken clouds
# 7       11.99     overcast clouds
# 8       14.65          light rain
# 9       20.80     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
